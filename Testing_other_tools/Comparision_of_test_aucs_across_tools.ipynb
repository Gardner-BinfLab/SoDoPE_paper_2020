# %%
import os
root_dir = os.path.abspath(os.path.join(os.getcwd(), "../"))
os.chdir(root_dir)

import pickle
import pandas as pd
import numpy as np



import functions


#need to run optimisation scripts first inside cross validation dir

# %% [markdown]
# ## At id = 10%

# %%
# [wilkinson, proteinsol, parsnip, deepsol1, deepsol2, deepsol3, ccsol, camsol]


cross_val_df = pd.read_pickle('results/cross_validation_10_with_histag.pkl.gz')

#Other  tools AUC for testing set
wilkinson = [0.5518240048802806,
 0.5239730479587792,
 0.6021382258383174,
 0.5299106142398806,
 0.5683178401150324,
 0.53041997045434,
 0.5010110029472757,
 0.5773884312904276,
 0.5451334942754021,
 0.5649035306470666]

proteinsol = [0.7054460881500686,
 0.667889021006738,
 0.7283977225784436,
 0.6244890317346398,
 0.6740653616205443,
 0.6627905574482197,
 0.6596430269913522,
 0.6738998247165215,
 0.6906058034753926,
 0.7317141662367947]


parsnip = [0.5482049717858777,
 0.6452396825396826,
 0.5907226802210368,
 0.5956280122660751,
 0.6156078933427511,
 0.5679625553981127,
 0.6147496433181602,
 0.6383529557758232,
 0.6234747352821665,
 0.6393517430414173]

deepsol1 = [0.6490590208937014,
 0.6547031311930243,
 0.6907475259083643,
 0.6081678330406761,
 0.6440333240836508,
 0.5868114805993547,
 0.6369383272026115,
 0.6571175950486297,
 0.6195517723546143,
 0.6920886278795055]

deepsol2 = [0.6827802348635047,
 0.6811969877130399,
 0.692506181487269,
 0.6385635302694621,
 0.6615388738931913,
 0.6357412041363923,
 0.6606491771244811,
 0.6651154854421641,
 0.6939521237182398,
 0.7162845639878272]

deepsol3 = [0.6555330181485435,
 0.6816535869996037,
 0.6931916829810035,
 0.6303823645384478,
 0.6711359451073384,
 0.6229581838463626,
 0.6562881148111123,
 0.6432686490762716,
 0.6664286397208212,
 0.6902175406038149]

ccsol = [0.5463306390117431,
 0.5116813317479192,
 0.5028452802174447,
 0.5072010711540152,
 0.5068962690144043,
 0.5466052639512798,
 0.5146231466293971,
 0.5119611584221384,
 0.5244893873843727,
 0.5181553460290522]

camsol = [0.6593030349245083,
 0.6403091557669442,
 0.6862169297914757,
 0.6606277144080995,
 0.6684004565979668,
 0.658153697729808,
 0.7004325475009626,
 0.64355406642158,
 0.6684663097258408,
 0.6372563084333231]

flexibility = [0.6643632758883635,
 0.6687641696393183,
 0.6969155426238243,
 0.6513430557958907,
 0.683880010595091,
 0.6433989568573065,
 0.7025386688407274,
 0.6813160221508678,
 0.6566436407964242,
 0.6746017453306759] #inside same folder as other tools


colors = {
    'SWI':'black',
    'Protein-Sol':'#039be5',
    'Flexibility':'#7b1fa2',
    'DeepSol S2':'#43a047',
    'DeepSol S3':'#2ecc71',
    'CamSol':'white',
    'DeepSol S1':'#00897b',
    'PaRSnIP':'#eeb932', 
    'Wilkinson-Harrison': 'lightgrey',
    'ccSOL':'white',}
new_df = pd.DataFrame({
    'SWI':cross_val_df['aucs_test'].values,
    'Protein-Sol':proteinsol,
    'DeepSol S2':deepsol2,
    'Flexibility':flexibility,
    'DeepSol S3':deepsol3,
    'CamSol':camsol,

    'DeepSol S1':deepsol1,
    'PaRSnIP':parsnip, 
    'Wilkinson-Harrison': wilkinson,
    'ccSOL':ccsol,})

functions.plt.figure(figsize=(4, 4))

functions.sns.swarmplot(data=new_df, color=".25", size=3)
ax = functions.sns.boxplot(data=new_df, fliersize="0", palette=colors)
for patch in ax.artists:
    r, g, b, a = patch.get_facecolor()
    patch.set_facecolor((r, g, b, .55))
ax.set_xticklabels(labels= new_df.columns, rotation=45, ha='right')
functions.plt.savefig('figs/cross_validation_test_train_with_all_tools_10.pdf')

# %% [markdown]
# ### At id = 40 %

# %%
# [wilkinson, proteinsol, parsnip, deepsol1, deepsol2, deepsol3, ccsol, camsol]
functions.plt.figure(figsize=(10, 10))


cross_val_df = pd.read_pickle('results/cross_validation_40_with_histag.pkl.gz')
# cross_val_df_1 = pd.read_pickle('results/cross_validation_40_without_histag.pkl.gz')

#Other  tools AUC for testing set
wilkinson = [0.5265999369482977,
 0.5093556085918854,
 0.5272760593169419,
 0.5361450241568776,
 0.5760466671667166,
 0.5830896123553708,
 0.5865624659161143,
 0.5567597713970309,
 0.5326756657422567,
 0.5741950923769106]

proteinsol = [0.6526756106674139,
 0.7006622911694511,
 0.7135833513591463,
 0.7099738892572943,
 0.6530996849684968,
 0.696177749557454,
 0.6616303307197305,
 0.6988604348976002,
 0.6646463296468308,
 0.6598950189859281]


parsnip = [0.5953394283312317,
 0.6207144988066826,
 0.615638554506789,
 0.5871364626752558,
 0.6187509375937594,
 0.6357493778701352,
 0.5778233576111589,
 0.6071188321470051,
 0.5903454843128737,
 0.6320224002042184]

deepsol1 = [0.6165697538648358,
 0.6776103818615752,
 0.6706428605763453,
 0.635398410856385,
 0.6265282778277828,
 0.6853465968855025,
 0.6040179599355284,
 0.6727674413256213,
 0.6168816198336062,
 0.6251124796579343]

deepsol2 = [0.6580043552379617,
 0.6903356205250597,
 0.6861225274593218,
 0.6803417487684729,
 0.6467912416241625,
 0.6980970522589086,
 0.6491268465891877,
 0.6981144279751159,
 0.639075812756858,
 0.6729506365870003]

deepsol3 = [0.6339279459156508,
 0.6786530429594273,
 0.6837551373566948,
 0.6577894088669951,
 0.6299114286428643,
 0.6972376151260936,
 0.6588475708035919,
 0.6734315168519944,
 0.6411006047646095,
 0.6539742812470085]

ccsol = [0.5064498436087105,
 0.514922247968955,
 0.474762227050903,
 0.5228004128969579,
 0.5494138356151086,
 0.4785176531671859,
 0.5400849936193727,
 0.4984259990613231,
 0.4810330694393511,
 0.5159527854779575]

camsol = [0.6558646840409135,
 0.668298031026253,
 0.6591589155670922,
 0.6417884378552483,
 0.6558796504650466,
 0.6696522486467072,
 0.6743398330041083,
 0.6403024849648701,
 0.6663887867954159,
 0.6927981109799293]

flexibility = [0.6560427467189762,
 0.6887902744630072,
 0.6886100896483764,
 0.6529225085259568,
 0.6525980723072307,
 0.6895379563354627,
 0.6771816716555377,
 0.6992528431631844,
 0.6565538440976979,
 0.6690002871821054] #inside same folder as other tools


colors = {
    'SWI':'black',
    'SWI_noTag': 'white',
    'Protein-Sol':'#039be5',
    'Flexibility':'#7b1fa2',
    'DeepSol S2':'#43a047',
    'DeepSol S3':'#2ecc71',
    'CamSol':'white',
    'DeepSol S1':'#00897b',
    'PaRSnIP':'#eeb932', 
    'Wilkinson-Harrison': 'lightgrey',
    'ccSOL':'white',}
new_df = pd.DataFrame({
    'SWI':cross_val_df['aucs_test'].values,
#     'SWI_noTag':cross_val_df_1['aucs_test'].values,
    'Protein-Sol':proteinsol,
    'DeepSol S2':deepsol2,
    'Flexibility':flexibility,
    'CamSol':camsol,
    'DeepSol S3':deepsol3,
    'DeepSol S1':deepsol1,
    'PaRSnIP':parsnip, 
    'Wilkinson-Harrison': wilkinson,
    'ccSOL':ccsol,})

functions.plt.figure(figsize=(4, 4))

functions.sns.swarmplot(data=new_df, color=".25", size=3)
ax = functions.sns.boxplot(data=new_df, fliersize="0", palette=colors)
for patch in ax.artists:
    r, g, b, a = patch.get_facecolor()
    patch.set_facecolor((r, g, b, .55))
ax.set_xticklabels(labels= new_df.columns, rotation=45, ha='right')
functions.plt.savefig('figs/cross_validation_test_train_with_all_tools_40.pdf')

# %% [markdown]
# ### At id = 90%

# %%
# [wilkinson, proteinsol, parsnip, deepsol1, deepsol2, deepsol3, ccsol, camsol]
functions.plt.figure(figsize=(10, 10))


cross_val_df = pd.read_pickle('results/cross_validation_90_with_histag.pkl.gz')
# cross_val_df_1 = pd.read_pickle('results/cross_validation_90_without_histag.pkl.gz')

#Other  tools AUC for testing set
wilkinson = [0.5830321031935065,
 0.5460816607465494,
 0.5795801343048652,
 0.5441749795968693,
 0.5257228695417189,
 0.5476832706766918,
 0.5403504471758573,
 0.5682634491361643,
 0.5184417624794687,
 0.5542280285035629]

proteinsol = [0.6915776986951365,
 0.6657182188026203,
 0.7105165117990209,
 0.6556597403664931,
 0.6871973803430352,
 0.6733975563909773,
 0.6546866779855565,
 0.6931609041776894,
 0.694582589445119,
 0.6963072050673]

parsnip = [0.6030736371476697,
 0.6096486645936013,
 0.6233782361542737,
 0.6226521721260942,
 0.6094803605207522,
 0.6100417163289631,
 0.594447964991152,
 0.563556366697699,
 0.6449360851246162,
 0.5946017418844022]

deepsol1 = [0.6520005728821264,
 0.6490041297427515,
 0.670662800408565,
 0.6251489868891538,
 0.6523311449872038,
 0.6291165413533835,
 0.6237654837629728,
 0.6516789720616838,
 0.6544911804613297,
 0.628652414885194]

deepsol2 = [0.6975011130726096,
 0.658217696439326,
 0.7065488368627427,
 0.6563144019680948,
 0.694170945333736,
 0.6524686716791981,
 0.6540514850064566,
 0.6536484497660284,
 0.6982817967578376,
 0.6643515439429929]

deepsol3 = [0.6860154491364736,
 0.6296505696832635,
 0.7013269047478601,
 0.6528884374431208,
 0.686111685132493,
 0.639984335839599,
 0.6345831938399732,
 0.6323836210737187,
 0.7019438691708919,
 0.6479746634996041]

ccsol = [0.5001105288885153,
 0.5238120844139084,
 0.5108086543745323,
 0.5177389808416072,
 0.5070260217139042,
 0.5454370300751881,
 0.502968219427041,
 0.5402252762952926,
 0.520281368278226,
 0.5260870942201109]

camsol = [0.7026072363730334,
 0.641660316367793,
 0.6942530805363503,
 0.6769024818426815,
 0.6821949164666423,
 0.6233114035087719,
 0.645215577024248,
 0.6592189069859618,
 0.6782103834892523,
 0.6216864608076009]

flexibility = [0.7061846361731474,
 0.6580118238468062,
 0.7016063184757672,
 0.6878643940416987,
 0.6954966697928755,
 0.6279010025062657,
 0.6529156105026542,
 0.6853843861282404,
 0.6786002999357281,
 0.6365827395091053] #inside same folder as other tools


colors = {
    'SWI':'black',
    'SWI_noTag':'white',
    'Protein-Sol':'#039be5',
    'Flexibility':'#7b1fa2',
    'DeepSol S2':'#43a047',
    'DeepSol S3':'#2ecc71',
    'CamSol':'white',
    'DeepSol S1':'#00897b',
    'PaRSnIP':'#eeb932', 
    'Wilkinson-Harrison': 'lightgrey',
    'ccSOL':'white',}
new_df = pd.DataFrame({
    'SWI':cross_val_df['aucs_test'].values,
#     'SWI_noTag': cross_val_df_1['aucs_test'].values,
    'Protein-Sol':proteinsol,
    'Flexibility':flexibility,
    'CamSol':camsol,
    'DeepSol S2':deepsol2,
    'DeepSol S3':deepsol3,
    'DeepSol S1':deepsol1,
    'PaRSnIP':parsnip, 
    'Wilkinson-Harrison': wilkinson,
    'ccSOL':ccsol,})

functions.plt.figure(figsize=(4, 4))

functions.sns.swarmplot(data=new_df, color=".25", size=3)
ax = functions.sns.boxplot(data=new_df, fliersize="0", palette=colors)
for patch in ax.artists:
    r, g, b, a = patch.get_facecolor()
    patch.set_facecolor((r, g, b, .55))
ax.set_xticklabels(labels= new_df.columns, rotation=45, ha='right')
functions.plt.savefig('figs/cross_validation_test_train_with_all_tools_90.pdf')
