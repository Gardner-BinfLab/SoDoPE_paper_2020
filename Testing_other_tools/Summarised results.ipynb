# %%
import pandas as pd
import seaborn as sns

# %%
results = pd.DataFrame({
            'ecoli (w3100) Spearman':[0.43537181844707445, -0.023607926986625213, 0.29499757513785024,\
                                     0.5388515733226185, \
                                      -0.0681159607391838, 0.5040987724767835, 0.3725351614547515,\
                                      0.3885479809674715, 0.23380470782222829, 0.34644352215260077],
            'ecoli (w3100) (p)':[4.5274663494369577e-148, 0.18197039385012695, 3.566733572070972e-65,\
                                  2.3750350418632384e-240, \
                                  0.00011573523231670192, 8.502081e-183, 7.72623618919182e-106, \
                                9.523368492390249e-116, 5.817061203361031e-41, 7.482753704456904e-91],
            'pET (AUC)':[0.66, 0.51, 0.61, 0.68, 0.55, 0.72, 0.67, 0.64, 0.67, 0.66]},
            index = ['camsol', 'ccsol', 'parsnip',\
                      'ProteinSol', \
                    'Wilkinson', 'SWI', 'Flexibility',\
                     'DeepSol S1', 'DeepSol S2', 'DeepSol S3'])

# %%
results.sort_values(['pET (AUC)', 'ecoli (w3100) Spearman'], ascending=False)
# Out:
#              ecoli (w3100) Spearman  ecoli (w3100) (p)  pET (AUC)
# SWI                        0.504099      8.502081e-183       0.72
# ProteinSol                 0.538852      2.375035e-240       0.68
# Flexibility                0.372535      7.726236e-106       0.67
# DeepSol S2                 0.233805       5.817061e-41       0.67
# camsol                     0.435372      4.527466e-148       0.66
# DeepSol S3                 0.346444       7.482754e-91       0.66
# DeepSol S1                 0.388548      9.523368e-116       0.64
# parsnip                    0.294998       3.566734e-65       0.61
# Wilkinson                 -0.068116       1.157352e-04       0.55
# ccsol                     -0.023608       1.819704e-01       0.51

# %%
results.sort_values(['pET (AUC)', 'ecoli (w3100) Spearman'], ascending=False).round(2)
# Out:
#              ecoli (w3100) Spearman  ecoli (w3100) (p)  pET (AUC)
# SWI                            0.50               0.00       0.72
# ProteinSol                     0.54               0.00       0.68
# Flexibility                    0.37               0.00       0.67
# DeepSol S2                     0.23               0.00       0.67
# camsol                         0.44               0.00       0.66
# DeepSol S3                     0.35               0.00       0.66
# DeepSol S1                     0.39               0.00       0.64
# parsnip                        0.29               0.00       0.61
# Wilkinson                     -0.07               0.00       0.55
# ccsol                         -0.02               0.18       0.51

# %%
results.to_csv('summary_results.csv')
